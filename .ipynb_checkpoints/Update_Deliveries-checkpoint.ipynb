# %%
import pandas as pd
import sys
import os
import gspread 
from oauth2client.service_account import ServiceAccountCredentials
import sqlalchemy
import sqlite3
import re
import numpy as np
from sqlalchemy import create_engine
from sqlalchemy import Table, Column, Integer, String, MetaData, ForeignKey, UniqueConstraint, PrimaryKeyConstraint
from df2gspread import df2gspread as d2g

# %%
scope = ['https://spreadsheets.google.com/feeds',
         'https://www.googleapis.com/auth/drive']

credentials = ServiceAccountCredentials.from_json_keyfile_name(
         'covid19tracker-273614-fa3cbba84de0.json', scope) # Your json file here

gc = gspread.authorize(credentials)

# wks = gc.open_by_url("https://docs.google.com/spreadsheets/d/1nTiL-AuU6Jn2Ovr3iO_TDIJODZ0AoHzYzxGE-YPVGts/edit#gid=227207881")
# data = wks.get_worksheet(1).get_all_values()
# headers = data.pop(1)
# df = pd.DataFrame(data, columns=headers)

# %%
wks = gc.open_by_url("https://docs.google.com/spreadsheets/d/1nTiL-AuU6Jn2Ovr3iO_TDIJODZ0AoHzYzxGE-YPVGts/edit#gid=227207881")
# data = wks.get_worksheet(1).get_all_values()
# headers = data.pop(1)
# df = pd.DataFrame(data, columns=headers)

# %%
data = wks.get_worksheet(1).get_all_values()
headers = data.pop(1)
social_services_df = pd.DataFrame(data, columns=headers)

# %%
social_services_df = social_services_df.reset_index(drop=True)

# %%
social_services_df.rename(columns={'Social Services agencies':'Agency'}, inplace=True)

# %%
social_services_df = social_services_df.reset_index(drop=True)

# %%
social_services_df = social_services_df.loc[social_services_df.Agency != '']

# %%
#social_services_df[social_services_df['Agency'] == '...']

# %%
data_clinics = wks.get_worksheet(0).get_all_values()
headers = data_clinics.pop(1)
clinics_df = pd.DataFrame(data_clinics, columns=headers)

# %%
social_services_df.columns
# Out:
# Index(['Agency', 'RC Kit Masks Distributed', 'Confirmed #', 'Address',
#        'Agency POC', 'Agency CELL', 'MCW POC', 'MCW CELL', '',
#        'Who will distrubte?', 'Number Distributed LAST',
#        'Date of Last Distribution', 'Previous Total', 'Total Delivered',
#        'Notes', 'Box #', 'Kit #', 'All Distributions', 'Verification Photo'],
#       dtype='object')

# %%
#clinics_df

# %%
engine = create_engine('sqlite:///mcw_ppe_db.sqlite', echo=False)

# %%
deliveries_df = social_services_df[['Agency','Number Distributed LAST',\
                                    'Date of Last Distribution',\
                                    'Who Distributes Next','Box #','Kit #']]

deliveries_df = deliveries_df[(deliveries_df.Agency != '') &\
                              (~deliveries_df['Number Distributed LAST'].str.contains('ADD'))\
                             & pd.notnull(deliveries_df['Date of Last Distribution'])
                             & (deliveries_df['Number Distributed LAST'].astype('str') != '')]

# %%
deliveries_df
# Out:
#                                  Agency Number Distributed LAST  \
# 12            Metcalf Community Bridges                    1400
# 13           All People's Church Pantry                    1400
# 14             Rogers Memorial Hospital                    1400
# 16  Meals on Wheels - Direct to Seniors                     700
# 20   Milwaukee County Homeless Outreach                    1400
# 21                        Maanaan Sabir                    4200
# 25        Sojourner Family Peace Center                   14700
# 26          Milwaukee Police Department                   14000
#
#    Date of Last Distribution Who Distributes Next Box # Kit #
# 12                 4/10/2020       Jonathan Horng
# 13                 4/10/2020       Jonathan Horng
# 14                 4/10/2020       Jonathan Horng
# 16                 4/10/2020       Jonathan Horng
# 20                 4/10/2020       Jonathan Horng
# 21                 4/10/2020    Na'il O. Scoggins    33
# 25                 4/10/2020
# 26                 4/10/2020       Jonathan Horng

# %%
#deliveries_df[deliveries_df['Agency']== 'Milwaukee County Office of Corrections']

# %%
#only for first time
total_delivered_df = social_services_df[['Agency','Total Delivered']]

# %%
poc_df = social_services_df[['Agency','Agency POC','Agency CELL']]

# %%
# Global Variables
SQLITE                  = 'sqlite'

# Table Names
DELIVERIES          = 'deliveries'
TOTAL       = 'total_items_delivered'
POC = 'points_of_contact'

# %%
class MyDatabase:
    # http://docs.sqlalchemy.org/en/latest/core/engines.html
    DB_ENGINE = {
        SQLITE: 'sqlite:///{DB}'
    }

    # Main DB Connection Ref Obj
    db_engine = None
    def __init__(self, dbtype, username='', password='', dbname=''):
        dbtype = dbtype.lower()
        if dbtype in self.DB_ENGINE.keys():
            engine_url = self.DB_ENGINE[dbtype].format(DB=dbname)
            self.db_engine = create_engine(engine_url)
            print(self.db_engine)
        else:
            print("DBType is not found in DB_ENGINE")
    
    def create_db_tables(self):
        metadata = MetaData()
        deliveries = Table(DELIVERIES, metadata,
                      Column('agency', String),
                      Column('date_distributed',String),
                      Column('number_distributed', Integer),
                      Column('distributor', String),
                      Column('box_num', String),
                      Column('kit_num', String),
                      PrimaryKeyConstraint('agency', 'date_distributed','box_num','kit_num', name = 'pk_agency_date')
                      )
        total = Table(TOTAL, metadata,
                        #Column('id', Integer, primary_key=True),
                        Column('agency', None, ForeignKey('deliveries.agency')),
                        Column('total_distributed', Integer, nullable=False),
                        UniqueConstraint('agency', 'total_distributed', sqlite_on_conflict='REPLACE')
                        )
        poc = Table(POC, metadata,
                    Column('agency_poc', String, primary_key=True),
                    Column('agency', None, ForeignKey('deliveries.agency')),
                    Column('agency_cell', String),
                    Column('box_num', String),
                    Column('distributor', None, ForeignKey('deliveries.distributor'))
                   )
        try:
            metadata.create_all(self.db_engine)
            print("Tables created")
        except Exception as e:
            print("Error occurred during Table creation!")
            print(e)
    # Insert, Update, Delete
    def execute_query(self, query=''):
        if query == '' : return
        print (query)
        with self.db_engine.connect() as connection:
            try:
                excute = connection.execute(query)
            except Exception as e:
                print(e)
            if 'select' in query:
                execute.fetchall()
                
    def print_all_data(self, table='', query=''):
        query = query if query != '' else "SELECT * FROM '{}';".format(table)
        print(query)
        with self.db_engine.connect() as connection:
            try:
                result = connection.execute(query)
            except Exception as e:
                print(e)
            else:
                for row in result:
                    print(row) # print(row[0], row[1], row[2])
                result.close()
        print("\n")
#     def sample_insert(self):
#     # Insert Data
#         query = "INSERT INTO {}(id, first_name, last_name) " \
#                 "VALUES (3, 'Terrence','Jordan');".format(USERS)
#         self.execute_query(query)
#         self.print_all_data(USERS)

# %%
dbms = MyDatabase('sqlite', dbname='mcw_ppe_db.sqlite')
# Out:
# Engine(sqlite:///mcw_ppe_db.sqlite)

# %%
dbms.create_db_tables()
# Out:
# Tables created

# %%
#'Agency','Number Distributed LAST','Date of Last Distribution','Who will distribute','Box #','Kit #'
def add_deliveries(df):
    df = df.rename(columns={'Who Distributes':'Who Distributes Next',\
                            'Who will distrubte?':'Who Distributes Next',\
                           'Who Will distribute?':'Who Distributes Next'})
    print(df.columns)
    for row in df.iterrows():
        insert_dict = {}
        
        if 'Date of Last Distribution' in df.columns:
            insert_dict['agency'] = row[1]['Agency']
            insert_dict['date_distributed'] = row[1]['Date of Last Distribution']
            insert_dict['number_distributed'] = row[1]['Number Distributed LAST']
            insert_dict['distributor'] = row[1]['Who Distributes Next']
            insert_dict['box'] = row[1]['Box #']
            insert_dict['kit'] = row[1]['Kit #']
        elif 'Timestamp' in df.columns:
            insert_dict['agency'] = row[1]['What agency did you drop the PPE off at?']
            insert_dict['date_distributed'] = row[1]['Date of Drop-Off']
            insert_dict['number_distributed'] = int(row[1]['Number of Units'])*700
            insert_dict['distributor'] = row[1]['Your Name']
            insert_dict['box'] = row[1]['Box Number']
            insert_dict['kit'] = row[1]['Kit Number']
            
        else:
            insert_dict['agency'] = row[1]['agency']
            insert_dict['date_distributed'] = row[1]['date_distributed']
            insert_dict['number_distributed'] = row[1]['number_distributed']
            insert_dict['distributor'] = row[1]['distributor']
            insert_dict['box'] = row[1]['box_num']
            insert_dict['kit'] = row[1]['kit_num']

        dbms.execute_query('INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)\
                           VALUES ("{0}","{1}","{2}","{3}","{5}","{4}")'.\
                              format(insert_dict['agency'],insert_dict['date_distributed'],\
                                     insert_dict['number_distributed'], insert_dict['distributor'] ,insert_dict['box'],
                                    insert_dict['kit']))

def add_total(df):
    df = df.rename(columns={'Total':'Total Delivered'})
    for row in df.iterrows():
        insert_dict = {}
        if 'Agency' in df.columns:
            insert_dict['agency'] = row[1]['Agency']
            insert_dict['total_distributed'] = row[1]['Total Delivered']
        else:
            insert_dict['agency'] = row[1]['agency']
            insert_dict['total_distributed'] = row[1]['total_distributed']
            
        dbms.execute_query('INSERT INTO total_items_delivered(agency, total_distributed)\
                           VALUES ("{0}","{1}")'.\
                              format(insert_dict['agency'],insert_dict['total_distributed']))

# %%
#dbms.print_all_data('deliveries')

# %%
#deliveries_qdf.drop(columns='Agency',inplace=True)

# %%
# pd.DataFrame({'agency':['Maanaan Sabir','Milwaukee Rescue Mission'],'date_distributed':['4/9/2020','4/9/2020'],
#               'number_distributed':[700,100],'distributor':['Jonathan Horng','Jonathan Horng'],'box_num':['',''],
#               'kit_num':['','']})
# Out:
#                      agency date_distributed  number_distributed  \
# 0             Maanaan Sabir         4/9/2020                 700
# 1  Milwaukee Rescue Mission         4/9/2020                 100
#
#       distributor box_num kit_num
# 0  Jonathan Horng
# 1  Jonathan Horng

# %%
# add_deliveries(pd.DataFrame({'agency':['Waukesha Womens Center'],'date_distributed':['4/8/2020'],
#               'number_distributed':[700],'distributor':['Katinka Hooyer'],'box_num':[''],
#               'kit_num':['']}))
# Out:
# Index(['agency', 'date_distributed', 'number_distributed', 'distributor',
#        'box_num', 'kit_num'],
#       dtype='object')
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Waukesha Womens Center","4/8/2020","700","Katinka Hooyer","","")

# %%
dbms.execute_query('DELETE FROM deliveries WHERE number_distributed <1')
# Out:
# DELETE FROM deliveries WHERE number_distributed <1

# %%
total_deliveries_df = pd.read_sql_query("SELECT * FROM total_items_delivered WHERE total_distributed > 0", engine)

# %%
#total_deliveries_df

# %%
url = 'https://docs.google.com/spreadsheets/d/1nTiL-AuU6Jn2Ovr3iO_TDIJODZ0AoHzYzxGE-YPVGts/edit#gid=1001217485'
spreadsheet_key = '1nTiL-AuU6Jn2Ovr3iO_TDIJODZ0AoHzYzxGE-YPVGts'
wks_name = 'Total Delivered'
d2g.upload(deliveries_qdf.groupby('agency').sum().reset_index(), spreadsheet_key, wks_name, credentials=credentials, row_names=True)
# Out:
# <Worksheet 'Total Delivered' id:1001217485>

# %%
clinics_df = clinics_df.drop(0,axis=0).rename(columns={'':'Agency'})

# %%
clinics_df  = clinics_df .loc[clinics_df .Agency != '']

# %%
#MAKE SURE TO REMOVE rows with no deliveries
add_deliveries(deliveries_df)
# Out:
# Index(['Agency', 'Number Distributed LAST', 'Date of Last Distribution',
#        'Who Distributes Next', 'Box #', 'Kit #'],
#       dtype='object')
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Metcalf Community Bridges","4/10/2020","1400","Jonathan Horng","","")
# (sqlite3.IntegrityError) UNIQUE constraint failed: deliveries.agency, deliveries.date_distributed
# [SQL: INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Metcalf Community Bridges","4/10/2020","1400","Jonathan Horng","","")]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("All People's Church Pantry","4/10/2020","1400","Jonathan Horng","","")
# (sqlite3.IntegrityError) UNIQUE constraint failed: deliveries.agency, deliveries.date_distributed
# [SQL: INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("All People's Church Pantry","4/10/2020","1400","Jonathan Horng","","")]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Rogers Memorial Hospital","4/10/2020","1400","Jonathan Horng","","")
# (sqlite3.IntegrityError) UNIQUE constraint failed: deliveries.agency, deliveries.date_distributed
# [SQL: INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Rogers Memorial Hospital","4/10/2020","1400","Jonathan Horng","","")]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Meals on Wheels - Direct to Seniors","4/10/2020","700","Jonathan Horng","","")
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Milwaukee County Homeless Outreach","4/10/2020","1400","Jonathan Horng","","")
# (sqlite3.IntegrityError) UNIQUE constraint failed: deliveries.agency, deliveries.date_distributed
# [SQL: INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Milwaukee County Homeless Outreach","4/10/2020","1400","Jonathan Horng","","")]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Maanaan Sabir","4/10/2020","4200","Na'il O. Scoggins","","33")
# (sqlite3.IntegrityError) UNIQUE constraint failed: deliveries.agency, deliveries.date_distributed
# [SQL: INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Maanaan Sabir","4/10/2020","4200","Na'il O. Scoggins","","33")]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Sojourner Family Peace Center","4/10/2020","14700","","","")
# (sqlite3.IntegrityError) UNIQUE constraint failed: deliveries.agency, deliveries.date_distributed
# [SQL: INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Sojourner Family Peace Center","4/10/2020","14700","","","")]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Milwaukee Police Department","4/10/2020","14000","Jonathan Horng","","")
# (sqlite3.IntegrityError) UNIQUE constraint failed: deliveries.agency, deliveries.date_distributed
# [SQL: INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Milwaukee Police Department","4/10/2020","14000","Jonathan Horng","","")]
# (Background on this error at: http://sqlalche.me/e/gkpj)

# %%
new_totals = deliveries_qdf[['agency','number_distributed']].groupby('agency').sum().\
          reset_index().rename(columns={'number_distributed':'total_distributed'})

new_totals.total_distributed = new_totals.total_distributed.astype(int)

add_total(new_totals)
# Out:
# INSERT INTO total_items_delivered(agency, total_distributed)                           VALUES ("All People's Church Pantry","1400")
# INSERT INTO total_items_delivered(agency, total_distributed)                           VALUES ("AyudaMutua MKE","1400")
# INSERT INTO total_items_delivered(agency, total_distributed)                           VALUES ("Dryhootch","1400")
# INSERT INTO total_items_delivered(agency, total_distributed)                           VALUES ("ELECTION POLL WORKERS","1400")
# INSERT INTO total_items_delivered(agency, total_distributed)                           VALUES ("Feeding America","700")
# INSERT INTO total_items_delivered(agency, total_distributed)                           VALUES ("Friedens Community Ministries","1400")
# INSERT INTO total_items_delivered(agency, total_distributed)                           VALUES ("Independence First","1400")
# INSERT INTO total_items_delivered(agency, total_distributed)                           VALUES ("Isaac Coggs Heritage Health Center","1400")
# INSERT INTO total_items_delivered(agency, total_distributed)                           VALUES ("MPS School District Feeding Locations","2800")
# INSERT INTO total_items_delivered(agency, total_distributed)                           VALUES ("Maanaan Sabir","4900")
# INSERT INTO total_items_delivered(agency, total_distributed)                           VALUES ("Masked Sewists of ","1400")
# INSERT INTO total_items_delivered(agency, total_distributed)                           VALUES ("Meals on Wheels - Direct to Seniors","700")
# INSERT INTO total_items_delivered(agency, total_distributed)                           VALUES ("Metcalf Community Bridges","1400")
# INSERT INTO total_items_delivered(agency, total_distributed)                           VALUES ("Milwaukee Community Care and Mutual Aid","1400")
# INSERT INTO total_items_delivered(agency, total_distributed)                           VALUES ("Milwaukee County Homeless Outreach","1400")
# INSERT INTO total_items_delivered(agency, total_distributed)                           VALUES ("Milwaukee County Office of Corrections","700")
# INSERT INTO total_items_delivered(agency, total_distributed)                           VALUES ("Milwaukee Police Department","14000")
# INSERT INTO total_items_delivered(agency, total_distributed)                           VALUES ("Milwaukee Rescue Mission: North","100")
# INSERT INTO total_items_delivered(agency, total_distributed)                           VALUES ("Milwaukee Rescue Mission: South","100")
# INSERT INTO total_items_delivered(agency, total_distributed)                           VALUES ("Outreach Community Health Centers, Inc.","1400")
# INSERT INTO total_items_delivered(agency, total_distributed)                           VALUES ("Pastors United","700")
# INSERT INTO total_items_delivered(agency, total_distributed)                           VALUES ("Progressive Community Health Centers","1400")
# INSERT INTO total_items_delivered(agency, total_distributed)                           VALUES ("Progressive Community Health Centers, Inc.","1400")
# INSERT INTO total_items_delivered(agency, total_distributed)                           VALUES ("Progressive Community Health Centers-12th
#  Street Urgent Care","1400")
# INSERT INTO total_items_delivered(agency, total_distributed)                           VALUES ("Rogers Memorial Hospital","1400")
# INSERT INTO total_items_delivered(agency, total_distributed)                           VALUES ("Sixteenth Street Community Health Centers","1400")
# INSERT INTO total_items_delivered(agency, total_distributed)                           VALUES ("Sojourner Family Peace Center","15400")
# INSERT INTO total_items_delivered(agency, total_distributed)                           VALUES ("StreetLife Communities","1400")
# INSERT INTO total_items_delivered(agency, total_distributed)                           VALUES ("United Way: Homeless Shelters","1400")

# %%
#add_total(clinics_df[['Agency','Total']])

# %%
total_delivered_df = pd.read_sql_query("SELECT * from total_items_delivered", engine)

# %%
#add_to_del = deliveries_qdf[(deliveries_qdf['Number Distributed LAST']!='') & (~deliveries_df['Number Distributed LAST'].str.contains('ADD'))]
#add_to_del['Number Distributed LAST'] = add_to_del['Number Distributed LAST'].astype(int)
# Out:
# /Users/yaz/.local/share/virtualenvs/mcw_distro-kEhQbVqt/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Who Distributes to Who Distributes Next
#deliveries_clinics_df = clinics_df[['Agency','Number Distributed LAST','Date of Last Distribution','Who Distributes','Box #','Kit #']]

# %%
#add_deliveries(add_to_del)

# %%
#deliveries_made = pd.read_sql_query("SELECT * FROM deliveries WHERE number_distributed >0", engine)
url = 'https://docs.google.com/spreadsheets/d/1nTiL-AuU6Jn2Ovr3iO_TDIJODZ0AoHzYzxGE-YPVGts/edit#gid=1001217485'
spreadsheet_key = '1nTiL-AuU6Jn2Ovr3iO_TDIJODZ0AoHzYzxGE-YPVGts'
wks_name = 'Deliveries Made'
d2g.upload(deliveries_qdf , spreadsheet_key, wks_name, credentials=credentials, row_names=True)
# Out:
# <Worksheet 'Deliveries Made' id:1065956448>

# %%
#dbms.execute_query('DELETE FROM deliveries')
# Out:
# DELETE FROM deliveries

# %%
#dbms.execute_query('ALTER TABLE deliveries DROP PRIMARY KEY;')

#dbms.execute_query('UPDATE deliveries SET distributor = "David Nelson" WHERE agency = "Milwaukee Rescue Mission: South"')

# %%
#deliveries_qdf.number_distributed.sum()
# Out:
# 29600

# %%
# data_deliveries = wks.worksheet('Deliveries Made').get_all_values()
# headers = data_deliveries.pop(0)
# deliveries_df1 = pd.DataFrame(data_deliveries, columns = headers)

# %%
#deliveries_qdf[pd.notna(deliveries_qdf.number_distributed)]

# %%
deliveries_qdf = pd.read_sql_query("SELECT * FROM deliveries WHERE number_distributed > 0 AND \
                                   number_distributed IS NOT NULL", engine)

# deliveries_qdf['agency'] = deliveries_qdf.agency.apply(lambda x: x.split('-')[0].strip())
# deliveries_qdf.number_distributed = deliveries_qdf.number_distributed.apply(lambda x: int(re.search(r'[0-9]+',x).group(0))\
#                                                                             if re.search(r'[0-9]+',x)\
#                                                                            else None)
#deliveries_qdf[deliveries_qdf.agency.str.contains('Maanaan')].agency.str.split('-').iloc[0][0].strip()

# %%
#deliveries_qdf

# %%
#Check total iterms delivered
#total_delivered_qdf = pd.read_sql_query("SELECT * FROM total_items_delivered", engine)

# %%
#total_delivered_qdf

# %%
#dbms.execute_query("DELETE FROM deliveries WHERE date_distributed = '' or date_distributed like '%ADD%'")
#Cleaning total_items_delievered table
# dbms.execute_query("DELETE FROM total_items_delivered WHERE total_distributed IS NULL OR \
#                     Agency IS NULL OR \
#                     total_distributed = '' OR \
#                     agency = '' OR \
#                     total_distributed = 0 OR \
#                     agency ='Maanaan Sabir - will distribute to 7 agencies on N. Side'")

# %%
#deliveries_qdf[['agency','number_distributed']].groupby('agency').sum().reset_index()

# %%
deliveries_qdf
# Out:
#                                     agency date_distributed  \
# 0                    ELECTION POLL WORKERS         4/8/2020
# 1                           Pastors United         4/8/2020
# 2    MPS School District Feeding Locations         4/8/2020
# 3                       Independence First         4/8/2020
# 4            Friedens Community Ministries         4/8/2020
# ..                                     ...              ...
# 104                     Planned Parenthood        4/20/2020
# 105                International Institute        4/20/2020
# 106                    Grocery Store Union        4/20/2020
# 107          Friedens Community Ministries        4/20/2020
# 108                          Maanaan Sabir        4/20/2020
#
#      number_distributed     distributor  box_num                 kit_num
# 0                  1400    Reggie Moore            Un-numbered Boxes (2)
# 1                   700   Ryan Spellecy           55 and Un-numbered Box
# 2                  2800  Katinka Hooyer                     9, 15, 38,45
# 3                  1400  Katinka Hooyer                          22 & 25
# 4                  1400    David Nelson                          11 & 66
# ..                  ...             ...      ...                     ...
# 104                1400  Mack Jablonski      322                      67
# 105                1400  Mack Jablonski      449                     155
# 106                2800  Mack Jablonski       NA      216, 218, 219, 220
# 107                4900       Jon Horng  451-455                 28, 291
# 108               10500       Jon Horng  456-465   194, 343, 51, 167, 47
#
# [109 rows x 6 columns]

# %%
#grab new deliveries
#PPE Distro Tracking
new_deliveries = wks.worksheet('PPE Distro Tracking')

# %%
deliveries_data = new_deliveries.get_all_values()
delivery_headers = deliveries_data.pop(0)
new_deliveries_df = pd.DataFrame(deliveries_data, columns=delivery_headers)

# %%
new_deliveries_df['What agency did you drop the PPE off at?'] = new_deliveries_df\
['What agency did you drop the PPE off at?'].apply(lambda x: re.split(r'[-|\(]',x)[0].strip())

# %%
dbms.execute_query('DELETE FROM deliveries WHERE agency = "Milwaukee Police Department"')
dbms.execute_query('DELETE FROM total_items_delivered WHERE agency = "Milwaukee Police Department"')
# Out:
# DELETE FROM deliveries WHERE agency = "Milwaukee Police Department"
# DELETE FROM total_items_delivered WHERE agency = "Milwaukee Police Department"

# %%
dbms.execute_query('UPDATE deliveries SET agency = "Maanaan Sabir" \
                WHERE agency = "Manaan Sabir"')
# Out:
# UPDATE deliveries SET agency = "Maanaan Sabir"                 WHERE agency = "Manaan Sabir"

# %%
new_deliveries_df
# Out:
#              Timestamp                 Email Address Date of Drop-Off  \
# 0   4/11/2020 19:33:39              nabenoza@mcw.edu        4/10/2020
# 1   4/11/2020 19:41:39              nabenoza@mcw.edu        4/10/2020
# 2   4/11/2020 19:43:04              nabenoza@mcw.edu        4/10/2020
# 3   4/12/2020 11:19:19             nscoggins@mcw.edu        4/10/2020
# 4   4/12/2020 11:21:34                jhorng@mcw.edu        4/10/2020
# 5   4/12/2020 11:23:37                jhorng@mcw.edu        4/10/2020
# 6   4/13/2020 11:50:13                jhorng@mcw.edu        4/13/2020
# 7   4/13/2020 16:51:07            mjablonski@mcw.edu        4/13/2020
# 8   4/14/2020 20:07:50            mjablonski@mcw.edu        4/14/2020
# 9   4/14/2020 20:09:49               joweiss@mcw.edu        4/14/2020
# 10  4/14/2020 20:10:34               joweiss@mcw.edu        4/14/2020
# 11  4/14/2020 20:11:12               joweiss@mcw.edu        4/14/2020
# 12  4/14/2020 20:12:35           chhernandez@mcw.edu        4/14/2020
# 13  4/14/2020 20:13:30           chhernandez@mcw.edu        4/14/2020
# 14  4/14/2020 20:14:49              jwatkins@mcw.edu        4/14/2020
# 15  4/14/2020 20:15:57              nabenoza@mcw.edu        4/14/2020
# 16  4/14/2020 20:16:48           chhernandez@mcw.edu        4/14/2020
# 17  4/14/2020 20:17:51              jwatkins@mcw.edu        4/14/2020
# 18  4/14/2020 20:18:49              nabenoza@mcw.edu        4/14/2020
# 19  4/14/2020 20:19:33              nabenoza@mcw.edu        4/14/2020
# 20  4/14/2020 20:20:25              jwatkins@mcw.edu        4/14/2020
# 21  4/14/2020 20:21:13            mjablonski@mcw.edu        4/14/2020
# 22  4/14/2020 20:21:52            mjablonski@mcw.edu        4/14/2020
# 23  4/14/2020 20:22:49            mjablonski@mcw.edu        4/14/2020
# 24  4/14/2020 20:23:39            mjablonski@mcw.edu        4/14/2020
# 25  4/14/2020 20:24:24            mjablonski@mcw.edu        4/14/2020
# 26  4/14/2020 20:25:34                astein@mcw.edu        4/14/2020
# 27  4/14/2020 20:27:04                astein@mcw.edu        4/14/2020
# 28  4/14/2020 20:27:48                astein@mcw.edu        4/14/2020
# 29  4/14/2020 20:28:44                jhorng@mcw.edu        4/14/2020
# 30  4/14/2020 20:33:58               vcoates@mcw.edu        4/14/2020
# 31  4/14/2020 20:35:19               vcoates@mcw.edu        4/14/2020
# 32  4/15/2020 11:25:47             nscoggins@mcw.edu        4/15/2020
# 33  4/15/2020 11:26:46             nscoggins@mcw.edu        4/15/2020
# 34  4/15/2020 16:32:05              jwatkins@mcw.edu        4/15/2020
# 35  4/15/2020 16:33:38              jwatkins@mcw.edu        4/15/2020
# 36  4/15/2020 16:35:34              jwatkins@mcw.edu        4/15/2020
# 37  4/15/2020 16:36:56                jhorng@mcw.edu        4/15/2020
# 38  4/15/2020 16:37:59  michelle.horng@marquette.edu        4/15/2020
# 39  4/15/2020 16:38:59               joweiss@mcw.edu        4/15/2020
# 40  4/15/2020 16:40:17                jhorng@mcw.edu        4/15/2020
# 41  4/15/2020 16:40:58  michelle.horng@marquette.edu        4/15/2020
# 42  4/15/2020 16:41:56            mjablonski@mcw.edu        4/15/2020
# 43  4/15/2020 16:43:25            mjablonski@mcw.edu        4/15/2020
# 44  4/15/2020 16:44:32            mjablonski@mcw.edu        4/15/2020
# 45  4/15/2020 19:03:07                astein@mcw.edu        4/15/2020
# 46  4/15/2020 19:04:45                astein@mcw.edu        4/15/2020
# 47  4/16/2020 19:18:49              nabenoza@mcw.edu        4/16/2020
# 48  4/16/2020 19:19:54              nabenoza@mcw.edu        4/16/2020
# 49  4/16/2020 19:20:53           chhernandez@mcw.edu        4/16/2020
# 50  4/16/2020 19:23:06                astein@mcw.edu        4/16/2020
# 51  4/16/2020 19:23:53                astein@mcw.edu        4/16/2020
# 52  4/16/2020 19:24:45                astein@mcw.edu        4/16/2020
# 53  4/16/2020 19:25:24               joweiss@mcw.edu        4/16/2020
#
#    Time of Drop-Off            Your Name  \
# 0        4:00:00 PM     Nathalie Abenoza
# 1        4:00:00 PM     Nathalie Abenoza
# 2        4:00:00 PM     Nathalie Abenoza
# 3       11:00:00 AM       Na'il Scoggins
# 4        5:00:00 PM       Jonathan Horng
# 5        6:00:00 PM       Jonathan Horng
# 6       12:00:00 PM       Jonathan Horng
# 7        5:30:00 PM       Mack Jablonski
# 8                         Mack Jablonski
# 9                             Joan Weiss
# 10                            Joan Weiss
# 11                            Joan Weiss
# 12                   Christian Hernandez
# 13                   Christian Hernandez
# 14                         Jayla Watkins
# 15                      Nathalie Abenoza
# 16                   Christian Hernandez
# 17                         Jayla Watkins
# 18                      Nathalie Abenoza
# 19                      Nathalie Abenoza
# 20                         Jayla Watkins
# 21                        Mack Jablonski
# 22                        Mack Jablonski
# 23                        Mack Jablonski
# 24                        Mack Jablonski
# 25                        Mack Jablonski
# 26       5:00:00 PM           Drew Stein
# 27       5:00:00 PM           Drew Stein
# 28       5:00:00 PM           Drew Stein
# 29       3:30:00 PM       Jonathan Horng
# 30                          Venus Coates
# 31                          Venus Coates
# 32      10:00:00 AM       Na'il Scoggins
# 33      10:00:00 AM       Na'il Scoggins
# 34       1:00:00 PM        Jayla Watkins
# 35       1:00:00 PM        Jayla Watkins
# 36       1:00:00 PM        Jayla Watkins
# 37       2:00:00 PM       Jonathan Horng
# 38                        Michelle Horng
# 39                            Joan Weiss
# 40                        Jonathan Horng
# 41                        Michelle Horng
# 42       4:30:00 PM       Mack Jablonski
# 43       4:30:00 PM       Mack Jablonski
# 44       4:30:00 PM       Mack Jablonski
# 45       6:00:00 PM           Drew Stein
# 46       6:00:00 PM           Drew Stein
# 47      12:00:00 PM     Nathalie Abenoza
# 48      12:00:00 PM     Nathalie Abenoza
# 49      11:00:00 AM  Christian Hernandez
# 50       3:00:00 PM           Drew Stein
# 51       3:00:00 PM           Drew Stein
# 52       3:00:00 PM           Drew Stein
# 53       4:00:00 PM           Joan Weiss
#
#              What agency did you drop the PPE off at? Box or Kit?  \
# 0                          Metcalfe Community Bridges    Box, Kit
# 1              Rogers Memorial Hospital - West Allies    Box, Kit
# 2                          All People's Church Pantry    Box, Kit
# 3                      Manaan Sabir (Sherman Pheonix)    Box, Kit
# 4                            Wisconsin Heros Outdoors         Box
# 5   Milwaukee Police Department and Milwaukee Fire...    Box, Kit
# 6                                     Meals on Wheels    Box, Kit
# 7                         Milwaukee Housing Authority    Box, Kit
# 8                            Guest House of Milwaukee    Box, Kit
# 9                    Daniels-Mardak Boys & Girls Club    Box, Kit
# 10                        LaVarnway Boys & Girls Club    Box, Kit
# 11               Don & Sallie Davis Boys & Girls Club    Box, Kit
# 12                               Voces de la Frontera    Box, Kit
# 13                Community Advocates - Womens Center    Box, Kit
# 14                                    Benedict Center    Box, Kit
# 15                    Metcalfe Park Community Bridges    Box, Kit
# 16               Project Concern Cudahy / St. Francis    Box, Kit
# 17  Catholic Charities of the Archdiocese of Milwa...    Box, Kit
# 18              Running Rebels Community Organization    Box, Kit
# 19                                     House of Peace    Box, Kit
# 20                             City on a Hill--Clinic    Box, Kit
# 21                            Bread of Healing Clinic    Box, Kit
# 22                                       St. Mark AME    Box, Kit
# 23                       Health Care for the Homeless    Box, Kit
# 24           Northcott Neighborhood House Food Pantry    Box, Kit
# 25                        Center for Veteran’s Issues    Box, Kit
# 26              Ebenezer Stone Ministries Food Pantry    Box, Kit
# 27                  MacCanon Brown Homeless Sanctuary    Box, Kit
# 28                                      Street Angels    Box, Kit
# 29                                Grocery Store Union    Box, Kit
# 30                     Silver Spring Community Center    Box, Kit
# 31                               Next Door Foundation    Box, Kit
# 32  Hmong American Friendship Association Food Pantry    Box, Kit
# 33                          Bay View Community Center    Box, Kit
# 34                                    Cecilia Marquez    Box, Kit
# 35                                        Pathfinders    Box, Kit
# 36   Milwaukee Christian Center Emergency Food Pantry    Box, Kit
# 37                   Kenosha Community Health Center     Box, Kit
# 38            Milwaukee Dept of Neighborhood Services    Box, Kit
# 39                    Milwaukee County Transit System         Box
# 40            Racine Kenosha Community Action Agency     Box, Kit
# 41               Milwaukee Department of Public Works    Box, Kit
# 42                    Milwaukee Islamic Da'wah Center    Box, Kit
# 43                              Riverwest Food Pantry    Box, Kit
# 44                Hmong Wisconsin Chamber of Commerce    Box, Kit
# 45                                  Teens Grow Greens         Box
# 46                 Hmong American Women's Association    Box, Kit
# 47                                   Eastbrook Church    Box, Kit
# 48                 Salvation Army Distribution Center    Box, Kit
# 49                        UMOS/Latina Resource Center    Box, Kit
# 50                            WestCare Wisconsin, Inc    Box, Kit
# 51         United Methodist Children's Services of WI    Box, Kit
# 52               Southside Organizing Committee (SOC)    Box, Kit
# 53                               Safe and Sound, Inc.    Box, Kit
#
#              Box Number               Kit Number Number of Units  \
# 0                    59                      182               2
# 1                    52                      183               2
# 2                    94                      187               2
# 3            76, 99, 46            176, 177, 178               6
# 4                    96                       NA               1
# 5   95, 68, 69, 49, 106  210, 211, 212, 213, 214              10
# 6                   190                      225               2
# 7                   189                      271               2
# 8                   127                      289               2
# 9                   132                      284               2
# 10                  144                      285               2
# 11                   44                      286               2
# 12                  171                      294               2
# 13                  104                      295               2
# 14                  173                      296               2
# 15                  174                      297               2
# 16                  175                      298               2
# 17                  172                      299               2
# 18                   77                      300               2
# 19                    3                      301               2
# 20                  199                      302               2
# 21                  151                      303               2
# 22                  139                      304               2
# 23                  153                      305               2
# 24                  135                      306               2
# 25                  100                      307               2
# 26                  101                      309               2
# 27                   74                      312               2
# 28                  161                      310               2
# 29        193, 200, 201                      311               4
# 30                  137                      288               2
# 31                  143                      287               2
# 32                   56                      308               2
# 33                   97                      313               2
# 34                  196                      338               2
# 35                  206                      337               2
# 36                  203                      336               2
# 37                   79                      202               2
# 38                   26                      334               2
# 39            208 & 191                       NA               2
# 40            209 & 205                329 & 330               4
# 41                  185                      328               2
# 42                  186                      327               2
# 43                  181                      314               2
# 44                  192                      315               2
# 45                  207                       NA               1
# 46                  102                      326               2
# 47                  129                      290               2
# 48                  105                      316               2
# 49                  111                       31               2
# 50                  170                      342               2
# 51                   35                      340               2
# 52                   36                      339               2
# 53                   30                      341               2
#
#                                               Address
# 0   \n2470 N 46th St Milwaukee, WI 53210 (Residenc...
# 1           11101 W Lincoln Ave, West Allis, WI 53227
# 2     2565 N 2nd St, Milwaukee WI (Susan's residence)
# 3                    2010 North Buffum, Milwaukee, WI
# 4   N20W 29957 Glen Cove Rd, Pewaukee, WI 53072 (P...
# 5                    picked up at MCW by Nick DeSiato
# 6                                       Pickup at MCW
# 7            650 W Reservoir Ave, Milwaukee, WI 53212
# 8            1216 N. 13th Street, Milwaukee, WI 53205
# 9                                      pick-up at MCW
# 10                                     pick-up at MCW
# 11                                     pick-up at MCW
# 12            1027 S. 5TH STREET, MILWAUKEE, WI 53204
# 13                               3025 W Mitchell St.
# 14              1849 N MLK Drive Suite 101, Milwaukee
# 15                                   2470 N 46th St.
# 16                      4611 S. Kirkwood Ave., Cudahy
# 17                                     1919 N 60th St
# 18                                   225 W Capitol Dr
# 19             1702 W. Walnut St. Milwaukee, WI 53205
# 20       2224 West Kilbourn Ave., Milwaukee, WI 53233
# 21               1621 North 16th, Milwaukee, WI 53205
# 22           1616 W Atkinson Ave, Milwaukee, WI 53206
# 23       210 West Capital Drive., Milwaukee, WI 53206
# 24                 2460 N 6th St, Milwaukee, WI 53212
# 25  315 West Court Street, 315 West Court Street, ...
# 26                          1127 S 35th St, Milwaukee
# 27                       13320 W North Ln, New Berlin
# 28                               445 W. Oklahoma Ave.
# 29              2001 N Mayfair Rd, Milwaukee WI 53226
# 30                           5460 N 64th St Milwaukee
# 31                2561 N 29th St, Milwaukee, WI 53210
# 32                  6165 N 87th St (Residence of POC)
# 33  1320 East Oklahoma Avenue, Milwaukee, Wisconsi...
# 34  Curative Building (1000 N. 92nd St. Wauwatosa,...
# 35  4200 N. Holton Street (Suite 400), Milwaukee, ...
# 36             807 S.14th Street, Milwaukee, WI 53204
# 37  Curative Building (1000 N. 92nd St. Wauwatosa,...      (care of Edwin M)
# 38                                     pick-up at MCW
# 39                                     pick-up at MCW
# 40  Curative Building (1000 N. 92nd St. Wauwatosa,...
# 41                                     pick-up at MCW
# 42           5135 N Teutonia Ave, Milwaukee, WI 53209
# 43                 2610 N. MLK Dr. Milwaukee (office)
# 44                         5421 N 118th Ct, Milwaukee
# 45              2305 East Lake Bluff Blvd, Milwaukee
# 46                     3826 W Helena St, Milwaukee WI
# 47                5385 N Green Bay Ave, Milwaukee, WI
# 48                     5880 N 60th st., Milwaukee, WI
# 49                                 2701 S. Chase Ave.
# 50                         335 W Wright St, Milwaukee
# 51                               3940 West Lisbon Ave
# 52               2843 S 9th St (Clarissa's residence)
# 53                                     pick-up at MCW

# %%
add_deliveries(new_deliveries_df)
# Out:
# Index(['Timestamp', 'Email Address', 'Date of Drop-Off', 'Time of Drop-Off',
#        'Your Name', 'What agency did you drop the PPE off at?', 'Box or Kit?',
#        'Box Number', 'Kit Number', 'Number of Units', 'Address', '', '', ''],
#       dtype='object')
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Metcalfe Community Bridges","4/10/2020","1400","Nathalie Abenoza","182","59")
# (sqlite3.IntegrityError) UNIQUE constraint failed: deliveries.agency, deliveries.date_distributed, deliveries.box_num, deliveries.kit_num
# [SQL: INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Metcalfe Community Bridges","4/10/2020","1400","Nathalie Abenoza","182","59")]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Rogers Memorial Hospital - West Allies","4/10/2020","1400","Nathalie Abenoza","183","52")
# (sqlite3.IntegrityError) UNIQUE constraint failed: deliveries.agency, deliveries.date_distributed, deliveries.box_num, deliveries.kit_num
# [SQL: INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Rogers Memorial Hospital - West Allies","4/10/2020","1400","Nathalie Abenoza","183","52")]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("All People's Church Pantry","4/10/2020","1400","Nathalie Abenoza","187","94")
# (sqlite3.IntegrityError) UNIQUE constraint failed: deliveries.agency, deliveries.date_distributed, deliveries.box_num, deliveries.kit_num
# [SQL: INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("All People's Church Pantry","4/10/2020","1400","Nathalie Abenoza","187","94")]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Manaan Sabir (Sherman Pheonix)","4/10/2020","4200","Na'il Scoggins","176, 177, 178","76, 99, 46")
# (sqlite3.IntegrityError) UNIQUE constraint failed: deliveries.agency, deliveries.date_distributed, deliveries.box_num, deliveries.kit_num
# [SQL: INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Manaan Sabir (Sherman Pheonix)","4/10/2020","4200","Na'il Scoggins","176, 177, 178","76, 99, 46")]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Wisconsin Heros Outdoors","4/10/2020","700","Jonathan Horng","NA","96")
# (sqlite3.IntegrityError) UNIQUE constraint failed: deliveries.agency, deliveries.date_distributed, deliveries.box_num, deliveries.kit_num
# [SQL: INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Wisconsin Heros Outdoors","4/10/2020","700","Jonathan Horng","NA","96")]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Milwaukee Police Department and Milwaukee Fire Department","4/10/2020","7000","Jonathan Horng","210, 211, 212, 213, 214","95, 68, 69, 49, 106")
# (sqlite3.IntegrityError) UNIQUE constraint failed: deliveries.agency, deliveries.date_distributed, deliveries.box_num, deliveries.kit_num
# [SQL: INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Milwaukee Police Department and Milwaukee Fire Department","4/10/2020","7000","Jonathan Horng","210, 211, 212, 213, 214","95, 68, 69, 49, 106")]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Meals on Wheels","4/13/2020","1400","Jonathan Horng","225","190")
# (sqlite3.IntegrityError) UNIQUE constraint failed: deliveries.agency, deliveries.date_distributed, deliveries.box_num, deliveries.kit_num
# [SQL: INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Meals on Wheels","4/13/2020","1400","Jonathan Horng","225","190")]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Milwaukee Housing Authority","4/13/2020","1400","Mack Jablonski","271","189")
# (sqlite3.IntegrityError) UNIQUE constraint failed: deliveries.agency, deliveries.date_distributed, deliveries.box_num, deliveries.kit_num
# [SQL: INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Milwaukee Housing Authority","4/13/2020","1400","Mack Jablonski","271","189")]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Guest House of Milwaukee","4/14/2020","1400","Mack Jablonski","289","127")
# (sqlite3.IntegrityError) UNIQUE constraint failed: deliveries.agency, deliveries.date_distributed, deliveries.box_num, deliveries.kit_num
# [SQL: INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Guest House of Milwaukee","4/14/2020","1400","Mack Jablonski","289","127")]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Daniels-Mardak Boys & Girls Club","4/14/2020","1400","Joan Weiss","284","132")
# (sqlite3.IntegrityError) UNIQUE constraint failed: deliveries.agency, deliveries.date_distributed, deliveries.box_num, deliveries.kit_num
# [SQL: INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Daniels-Mardak Boys & Girls Club","4/14/2020","1400","Joan Weiss","284","132")]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("LaVarnway Boys & Girls Club","4/14/2020","1400","Joan Weiss","285","144")
# (sqlite3.IntegrityError) UNIQUE constraint failed: deliveries.agency, deliveries.date_distributed, deliveries.box_num, deliveries.kit_num
# [SQL: INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("LaVarnway Boys & Girls Club","4/14/2020","1400","Joan Weiss","285","144")]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Don & Sallie Davis Boys & Girls Club","4/14/2020","1400","Joan Weiss","286","44")
# (sqlite3.IntegrityError) UNIQUE constraint failed: deliveries.agency, deliveries.date_distributed, deliveries.box_num, deliveries.kit_num
# [SQL: INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Don & Sallie Davis Boys & Girls Club","4/14/2020","1400","Joan Weiss","286","44")]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Voces de la Frontera","4/14/2020","1400","Christian Hernandez","294","171")
# (sqlite3.IntegrityError) UNIQUE constraint failed: deliveries.agency, deliveries.date_distributed, deliveries.box_num, deliveries.kit_num
# [SQL: INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Voces de la Frontera","4/14/2020","1400","Christian Hernandez","294","171")]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Community Advocates - Womens Center","4/14/2020","1400","Christian Hernandez","295","104")
# (sqlite3.IntegrityError) UNIQUE constraint failed: deliveries.agency, deliveries.date_distributed, deliveries.box_num, deliveries.kit_num
# [SQL: INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Community Advocates - Womens Center","4/14/2020","1400","Christian Hernandez","295","104")]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Benedict Center","4/14/2020","1400","Jayla Watkins","296","173")
# (sqlite3.IntegrityError) UNIQUE constraint failed: deliveries.agency, deliveries.date_distributed, deliveries.box_num, deliveries.kit_num
# [SQL: INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Benedict Center","4/14/2020","1400","Jayla Watkins","296","173")]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Metcalfe Park Community Bridges","4/14/2020","1400","Nathalie Abenoza","297","174")
# (sqlite3.IntegrityError) UNIQUE constraint failed: deliveries.agency, deliveries.date_distributed, deliveries.box_num, deliveries.kit_num
# [SQL: INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Metcalfe Park Community Bridges","4/14/2020","1400","Nathalie Abenoza","297","174")]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Project Concern Cudahy / St. Francis","4/14/2020","1400","Christian Hernandez","298","175")
# (sqlite3.IntegrityError) UNIQUE constraint failed: deliveries.agency, deliveries.date_distributed, deliveries.box_num, deliveries.kit_num
# [SQL: INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Project Concern Cudahy / St. Francis","4/14/2020","1400","Christian Hernandez","298","175")]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Catholic Charities of the Archdiocese of Milwaukee","4/14/2020","1400","Jayla Watkins","299","172")
# (sqlite3.IntegrityError) UNIQUE constraint failed: deliveries.agency, deliveries.date_distributed, deliveries.box_num, deliveries.kit_num
# [SQL: INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Catholic Charities of the Archdiocese of Milwaukee","4/14/2020","1400","Jayla Watkins","299","172")]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Running Rebels Community Organization","4/14/2020","1400","Nathalie Abenoza","300","77")
# (sqlite3.IntegrityError) UNIQUE constraint failed: deliveries.agency, deliveries.date_distributed, deliveries.box_num, deliveries.kit_num
# [SQL: INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Running Rebels Community Organization","4/14/2020","1400","Nathalie Abenoza","300","77")]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("House of Peace","4/14/2020","1400","Nathalie Abenoza","301","3")
# (sqlite3.IntegrityError) UNIQUE constraint failed: deliveries.agency, deliveries.date_distributed, deliveries.box_num, deliveries.kit_num
# [SQL: INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("House of Peace","4/14/2020","1400","Nathalie Abenoza","301","3")]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("City on a Hill--Clinic","4/14/2020","1400","Jayla Watkins","302","199")
# (sqlite3.IntegrityError) UNIQUE constraint failed: deliveries.agency, deliveries.date_distributed, deliveries.box_num, deliveries.kit_num
# [SQL: INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("City on a Hill--Clinic","4/14/2020","1400","Jayla Watkins","302","199")]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Bread of Healing Clinic","4/14/2020","1400","Mack Jablonski","303","151")
# (sqlite3.IntegrityError) UNIQUE constraint failed: deliveries.agency, deliveries.date_distributed, deliveries.box_num, deliveries.kit_num
# [SQL: INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Bread of Healing Clinic","4/14/2020","1400","Mack Jablonski","303","151")]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("St. Mark AME","4/14/2020","1400","Mack Jablonski","304","139")
# (sqlite3.IntegrityError) UNIQUE constraint failed: deliveries.agency, deliveries.date_distributed, deliveries.box_num, deliveries.kit_num
# [SQL: INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("St. Mark AME","4/14/2020","1400","Mack Jablonski","304","139")]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Health Care for the Homeless","4/14/2020","1400","Mack Jablonski","305","153")
# (sqlite3.IntegrityError) UNIQUE constraint failed: deliveries.agency, deliveries.date_distributed, deliveries.box_num, deliveries.kit_num
# [SQL: INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Health Care for the Homeless","4/14/2020","1400","Mack Jablonski","305","153")]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Northcott Neighborhood House Food Pantry","4/14/2020","1400","Mack Jablonski","306","135")
# (sqlite3.IntegrityError) UNIQUE constraint failed: deliveries.agency, deliveries.date_distributed, deliveries.box_num, deliveries.kit_num
# [SQL: INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Northcott Neighborhood House Food Pantry","4/14/2020","1400","Mack Jablonski","306","135")]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Center for Veteran’s Issues","4/14/2020","1400","Mack Jablonski","307","100")
# (sqlite3.IntegrityError) UNIQUE constraint failed: deliveries.agency, deliveries.date_distributed, deliveries.box_num, deliveries.kit_num
# [SQL: INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Center for Veteran’s Issues","4/14/2020","1400","Mack Jablonski","307","100")]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Ebenezer Stone Ministries Food Pantry","4/14/2020","1400","Drew Stein","309","101")
# (sqlite3.IntegrityError) UNIQUE constraint failed: deliveries.agency, deliveries.date_distributed, deliveries.box_num, deliveries.kit_num
# [SQL: INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Ebenezer Stone Ministries Food Pantry","4/14/2020","1400","Drew Stein","309","101")]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("MacCanon Brown Homeless Sanctuary","4/14/2020","1400","Drew Stein","312","74")
# (sqlite3.IntegrityError) UNIQUE constraint failed: deliveries.agency, deliveries.date_distributed, deliveries.box_num, deliveries.kit_num
# [SQL: INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("MacCanon Brown Homeless Sanctuary","4/14/2020","1400","Drew Stein","312","74")]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Street Angels","4/14/2020","1400","Drew Stein","310","161")
# (sqlite3.IntegrityError) UNIQUE constraint failed: deliveries.agency, deliveries.date_distributed, deliveries.box_num, deliveries.kit_num
# [SQL: INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Street Angels","4/14/2020","1400","Drew Stein","310","161")]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Grocery Store Union","4/14/2020","2800","Jonathan Horng","311","193, 200, 201")
# (sqlite3.IntegrityError) UNIQUE constraint failed: deliveries.agency, deliveries.date_distributed, deliveries.box_num, deliveries.kit_num
# [SQL: INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Grocery Store Union","4/14/2020","2800","Jonathan Horng","311","193, 200, 201")]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Silver Spring Community Center","4/14/2020","1400","Venus Coates","288","137")
# (sqlite3.IntegrityError) UNIQUE constraint failed: deliveries.agency, deliveries.date_distributed, deliveries.box_num, deliveries.kit_num
# [SQL: INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Silver Spring Community Center","4/14/2020","1400","Venus Coates","288","137")]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Next Door Foundation","4/14/2020","1400","Venus Coates","287","143")
# (sqlite3.IntegrityError) UNIQUE constraint failed: deliveries.agency, deliveries.date_distributed, deliveries.box_num, deliveries.kit_num
# [SQL: INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Next Door Foundation","4/14/2020","1400","Venus Coates","287","143")]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Hmong American Friendship Association Food Pantry","4/15/2020","1400","Na'il Scoggins","308","56")
# (sqlite3.IntegrityError) UNIQUE constraint failed: deliveries.agency, deliveries.date_distributed, deliveries.box_num, deliveries.kit_num
# [SQL: INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Hmong American Friendship Association Food Pantry","4/15/2020","1400","Na'il Scoggins","308","56")]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Bay View Community Center","4/15/2020","1400","Na'il Scoggins","313","97")
# (sqlite3.IntegrityError) UNIQUE constraint failed: deliveries.agency, deliveries.date_distributed, deliveries.box_num, deliveries.kit_num
# [SQL: INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Bay View Community Center","4/15/2020","1400","Na'il Scoggins","313","97")]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Cecilia Marquez","4/15/2020","1400","Jayla Watkins","338","196")
# (sqlite3.IntegrityError) UNIQUE constraint failed: deliveries.agency, deliveries.date_distributed, deliveries.box_num, deliveries.kit_num
# [SQL: INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Cecilia Marquez","4/15/2020","1400","Jayla Watkins","338","196")]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Pathfinders","4/15/2020","1400","Jayla Watkins","337","206")
# (sqlite3.IntegrityError) UNIQUE constraint failed: deliveries.agency, deliveries.date_distributed, deliveries.box_num, deliveries.kit_num
# [SQL: INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Pathfinders","4/15/2020","1400","Jayla Watkins","337","206")]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Milwaukee Christian Center Emergency Food Pantry","4/15/2020","1400","Jayla Watkins","336","203")
# (sqlite3.IntegrityError) UNIQUE constraint failed: deliveries.agency, deliveries.date_distributed, deliveries.box_num, deliveries.kit_num
# [SQL: INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Milwaukee Christian Center Emergency Food Pantry","4/15/2020","1400","Jayla Watkins","336","203")]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Kenosha Community Health Center ","4/15/2020","1400","Jonathan Horng","202","79")
# (sqlite3.IntegrityError) UNIQUE constraint failed: deliveries.agency, deliveries.date_distributed, deliveries.box_num, deliveries.kit_num
# [SQL: INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Kenosha Community Health Center ","4/15/2020","1400","Jonathan Horng","202","79")]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Milwaukee Dept of Neighborhood Services","4/15/2020","1400","Michelle Horng","334","26")
# (sqlite3.IntegrityError) UNIQUE constraint failed: deliveries.agency, deliveries.date_distributed, deliveries.box_num, deliveries.kit_num
# [SQL: INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Milwaukee Dept of Neighborhood Services","4/15/2020","1400","Michelle Horng","334","26")]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Milwaukee County Transit System","4/15/2020","1400","Joan Weiss","NA","208 & 191")
# (sqlite3.IntegrityError) UNIQUE constraint failed: deliveries.agency, deliveries.date_distributed, deliveries.box_num, deliveries.kit_num
# [SQL: INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Milwaukee County Transit System","4/15/2020","1400","Joan Weiss","NA","208 & 191")]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Racine Kenosha Community Action Agency ","4/15/2020","2800","Jonathan Horng","329 & 330","209 & 205")
# (sqlite3.IntegrityError) UNIQUE constraint failed: deliveries.agency, deliveries.date_distributed, deliveries.box_num, deliveries.kit_num
# [SQL: INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Racine Kenosha Community Action Agency ","4/15/2020","2800","Jonathan Horng","329 & 330","209 & 205")]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Milwaukee Department of Public Works","4/15/2020","1400","Michelle Horng","328","185")
# (sqlite3.IntegrityError) UNIQUE constraint failed: deliveries.agency, deliveries.date_distributed, deliveries.box_num, deliveries.kit_num
# [SQL: INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Milwaukee Department of Public Works","4/15/2020","1400","Michelle Horng","328","185")]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Milwaukee Islamic Da'wah Center","4/15/2020","1400","Mack Jablonski","327","186")
# (sqlite3.IntegrityError) UNIQUE constraint failed: deliveries.agency, deliveries.date_distributed, deliveries.box_num, deliveries.kit_num
# [SQL: INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Milwaukee Islamic Da'wah Center","4/15/2020","1400","Mack Jablonski","327","186")]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Riverwest Food Pantry","4/15/2020","1400","Mack Jablonski","314","181")
# (sqlite3.IntegrityError) UNIQUE constraint failed: deliveries.agency, deliveries.date_distributed, deliveries.box_num, deliveries.kit_num
# [SQL: INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Riverwest Food Pantry","4/15/2020","1400","Mack Jablonski","314","181")]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Hmong Wisconsin Chamber of Commerce","4/15/2020","1400","Mack Jablonski","315","192")
# (sqlite3.IntegrityError) UNIQUE constraint failed: deliveries.agency, deliveries.date_distributed, deliveries.box_num, deliveries.kit_num
# [SQL: INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Hmong Wisconsin Chamber of Commerce","4/15/2020","1400","Mack Jablonski","315","192")]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Teens Grow Greens","4/15/2020","700","Drew Stein","NA","207")
# (sqlite3.IntegrityError) UNIQUE constraint failed: deliveries.agency, deliveries.date_distributed, deliveries.box_num, deliveries.kit_num
# [SQL: INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Teens Grow Greens","4/15/2020","700","Drew Stein","NA","207")]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Hmong American Women's Association","4/15/2020","1400","Drew Stein","326","102")
# (sqlite3.IntegrityError) UNIQUE constraint failed: deliveries.agency, deliveries.date_distributed, deliveries.box_num, deliveries.kit_num
# [SQL: INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Hmong American Women's Association","4/15/2020","1400","Drew Stein","326","102")]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Eastbrook Church","4/16/2020","1400","Nathalie Abenoza","290","129")
# (sqlite3.IntegrityError) UNIQUE constraint failed: deliveries.agency, deliveries.date_distributed, deliveries.box_num, deliveries.kit_num
# [SQL: INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Eastbrook Church","4/16/2020","1400","Nathalie Abenoza","290","129")]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Salvation Army Distribution Center","4/16/2020","1400","Nathalie Abenoza","316","105")
# (sqlite3.IntegrityError) UNIQUE constraint failed: deliveries.agency, deliveries.date_distributed, deliveries.box_num, deliveries.kit_num
# [SQL: INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Salvation Army Distribution Center","4/16/2020","1400","Nathalie Abenoza","316","105")]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("UMOS/Latina Resource Center","4/16/2020","1400","Christian Hernandez","31","111")
# (sqlite3.IntegrityError) UNIQUE constraint failed: deliveries.agency, deliveries.date_distributed, deliveries.box_num, deliveries.kit_num
# [SQL: INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("UMOS/Latina Resource Center","4/16/2020","1400","Christian Hernandez","31","111")]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("WestCare Wisconsin, Inc","4/16/2020","1400","Drew Stein","342","170")
# (sqlite3.IntegrityError) UNIQUE constraint failed: deliveries.agency, deliveries.date_distributed, deliveries.box_num, deliveries.kit_num
# [SQL: INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("WestCare Wisconsin, Inc","4/16/2020","1400","Drew Stein","342","170")]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("United Methodist Children's Services of WI","4/16/2020","1400","Drew Stein","340","35")
# (sqlite3.IntegrityError) UNIQUE constraint failed: deliveries.agency, deliveries.date_distributed, deliveries.box_num, deliveries.kit_num
# [SQL: INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("United Methodist Children's Services of WI","4/16/2020","1400","Drew Stein","340","35")]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Southside Organizing Committee (SOC)","4/16/2020","1400","Drew Stein","339","36")
# (sqlite3.IntegrityError) UNIQUE constraint failed: deliveries.agency, deliveries.date_distributed, deliveries.box_num, deliveries.kit_num
# [SQL: INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Southside Organizing Committee (SOC)","4/16/2020","1400","Drew Stein","339","36")]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Safe and Sound, Inc.","4/16/2020","1400","Joan Weiss","341","30")
# (sqlite3.IntegrityError) UNIQUE constraint failed: deliveries.agency, deliveries.date_distributed, deliveries.box_num, deliveries.kit_num
# [SQL: INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Safe and Sound, Inc.","4/16/2020","1400","Joan Weiss","341","30")]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Social Development Commission","4/17/2020","1400","Jonathan Horng","335","204")
# (sqlite3.IntegrityError) UNIQUE constraint failed: deliveries.agency, deliveries.date_distributed, deliveries.box_num, deliveries.kit_num
# [SQL: INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Social Development Commission","4/17/2020","1400","Jonathan Horng","335","204")]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Project Ujima","4/17/2020","700","Joan Weiss","NA","138")
# (sqlite3.IntegrityError) UNIQUE constraint failed: deliveries.agency, deliveries.date_distributed, deliveries.box_num, deliveries.kit_num
# [SQL: INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Project Ujima","4/17/2020","700","Joan Weiss","NA","138")]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Greater New Birth Food Pantry","4/17/2020","1400","Venus Coates","318","20")
# (sqlite3.IntegrityError) UNIQUE constraint failed: deliveries.agency, deliveries.date_distributed, deliveries.box_num, deliveries.kit_num
# [SQL: INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Greater New Birth Food Pantry","4/17/2020","1400","Venus Coates","318","20")]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Salvation Army","4/17/2020","5600","Michelle Horng","319, 320, 321, 393, 394","1, 114, 16")
# (sqlite3.IntegrityError) UNIQUE constraint failed: deliveries.agency, deliveries.date_distributed, deliveries.box_num, deliveries.kit_num
# [SQL: INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Salvation Army","4/17/2020","5600","Michelle Horng","319, 320, 321, 393, 394","1, 114, 16")]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("UMOS/Latina Resource Center","4/17/2020","4200","Christian Hernandez","388-392","159")
# (sqlite3.IntegrityError) UNIQUE constraint failed: deliveries.agency, deliveries.date_distributed, deliveries.box_num, deliveries.kit_num
# [SQL: INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("UMOS/Latina Resource Center","4/17/2020","4200","Christian Hernandez","388-392","159")]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Pastors United","4/17/2020","2100","Ryan Spellecy","NA","55, 134, 156")
# (sqlite3.IntegrityError) UNIQUE constraint failed: deliveries.agency, deliveries.date_distributed, deliveries.box_num, deliveries.kit_num
# [SQL: INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Pastors United","4/17/2020","2100","Ryan Spellecy","NA","55, 134, 156")]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Sherman Park Community Association","4/17/2020","15400","Jayla Watkins","366-385","39, 131")
# (sqlite3.IntegrityError) UNIQUE constraint failed: deliveries.agency, deliveries.date_distributed, deliveries.box_num, deliveries.kit_num
# [SQL: INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Sherman Park Community Association","4/17/2020","15400","Jayla Watkins","366-385","39, 131")]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Metcalfe Community Bridges","4/17/2020","7700","Nathalie Abenoza","409-418","149")
# (sqlite3.IntegrityError) UNIQUE constraint failed: deliveries.agency, deliveries.date_distributed, deliveries.box_num, deliveries.kit_num
# [SQL: INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Metcalfe Community Bridges","4/17/2020","7700","Nathalie Abenoza","409-418","149")]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Wisconsin Heros Outdoors","4/17/2020","7700","Michelle Horng","419-428","50")
# (sqlite3.IntegrityError) UNIQUE constraint failed: deliveries.agency, deliveries.date_distributed, deliveries.box_num, deliveries.kit_num
# [SQL: INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Wisconsin Heros Outdoors","4/17/2020","7700","Michelle Horng","419-428","50")]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Waukesha Community Health Center","4/17/2020","1400","Michelle Horng","87","215")
# (sqlite3.IntegrityError) UNIQUE constraint failed: deliveries.agency, deliveries.date_distributed, deliveries.box_num, deliveries.kit_num
# [SQL: INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Waukesha Community Health Center","4/17/2020","1400","Michelle Horng","87","215")]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Riverworks Development Corporation","4/17/2020","1400","Mack Jablonski","317","17")
# (sqlite3.IntegrityError) UNIQUE constraint failed: deliveries.agency, deliveries.date_distributed, deliveries.box_num, deliveries.kit_num
# [SQL: INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Riverworks Development Corporation","4/17/2020","1400","Mack Jablonski","317","17")]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Havenwoods Economic Development Corporation","4/17/2020","700","Mack Jablonski","NA","142")
# (sqlite3.IntegrityError) UNIQUE constraint failed: deliveries.agency, deliveries.date_distributed, deliveries.box_num, deliveries.kit_num
# [SQL: INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Havenwoods Economic Development Corporation","4/17/2020","700","Mack Jablonski","NA","142")]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Guest House of Milwaukee","4/17/2020","2800","Mack Jablonski","386, 387","145, 136")
# (sqlite3.IntegrityError) UNIQUE constraint failed: deliveries.agency, deliveries.date_distributed, deliveries.box_num, deliveries.kit_num
# [SQL: INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Guest House of Milwaukee","4/17/2020","2800","Mack Jablonski","386, 387","145, 136")]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Pathfinders","4/17/2020","1400","Mack Jablonski","73","344")
# (sqlite3.IntegrityError) UNIQUE constraint failed: deliveries.agency, deliveries.date_distributed, deliveries.box_num, deliveries.kit_num
# [SQL: INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Pathfinders","4/17/2020","1400","Mack Jablonski","73","344")]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Tosa Pediatrics","4/20/2020","1400","Joan Weiss","436","345")
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("AyudaMutua MKE","4/20/2020","7000","Christian Hernandez","437-446","NA")
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Planned Parenthood","4/20/2020","1400","Mack Jablonski","322","67")
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("International Institute","4/20/2020","1400","Mack Jablonski","449","155")
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Grocery Store Union","4/20/2020","2800","Mack Jablonski","NA","216, 218, 219, 220")
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Friedens Community Ministries","4/20/2020","4900","Jon Horng","451-455","28, 291")
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num)                           VALUES ("Maanaan Sabir","4/20/2020","10500","Jon Horng","456-465","194, 343, 51, 167, 47")

# %%
dbms.execute_query('INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num) \
VALUES ("Maanaan Sabir","4/11/2020","1400","Zeno Franco","","")')
# Out:
# INSERT INTO deliveries(agency,date_distributed,number_distributed, distributor, box_num,kit_num) VALUES ("Manaan Sabir","4/11/2020","1400","Zeno Franco","","")

# %%
old_deliveries = wks.worksheet('Deliveries Made')
old_deliveries_data = old_deliveries.get_all_values()
old_deliveries_headers = old_deliveries_data.pop(0)
old_deliveries_data_df = pd.DataFrame(old_deliveries_data, columns=old_deliveries_headers)

# %%
#old_deliveries_data_df.drop(columns=[''],inplace=True)

# %%
#add_deliveries(old_deliveries_data_df)
